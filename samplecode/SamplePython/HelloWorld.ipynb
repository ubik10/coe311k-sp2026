# %% [markdown]
# # Let's start with Hello World!

# %% [markdown]
# # My sample notebook

# %% [markdown]
# ## Here's a sub heading

# %% [markdown]
# ### Here's a sub-sub heading

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
import numpy as np

print(np.pi)
# Output: 3.141592653589793
# Out:
# 3.141592653589793

# %%
import math
# math.atan(1) calculates arctan(1), which is equal to pi/4
pi_calculated = 4 * math.atan(1)

print(pi_calculated)
print(math.pi)
# Output: 3.141592653589793
print(math.pi == pi_calculated)
# Output: True (or very close depending on float precision)
# Out:
# 3.141592653589793
# 3.141592653589793
# True

# %%
number1 = 5.0/2
number2 = 5/2

# %%
print(number2)
# Out:
# 2.5
