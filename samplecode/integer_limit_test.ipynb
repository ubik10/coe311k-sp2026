# %%
i = 2147483647
print(i)
# Out:
# 2147483647

# %%
i = i + 1
print(i)
# Out:
# 2147483648

# %%
i = 1
print(i)
# Out:
# 1

# %%
print(i+.0000001)
# Out:
# 1.0000001

# %%
i+2**2
# Out:
# 5

# %%
i+2**-1
# Out:
# 1.5

# %%
i+2**-53
# Out:
# 1.0
